# %%
# !pip install -U diffusers
# Out:
# Requirement already satisfied: diffusers in /usr/local/lib/python3.11/dist-packages (0.33.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from diffusers) (8.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from diffusers) (3.18.0)
# Requirement already satisfied: huggingface-hub>=0.27.0 in /usr/local/lib/python3.11/dist-packages (from diffusers) (0.31.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from diffusers) (2.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from diffusers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from diffusers) (2.32.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from diffusers) (0.5.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from diffusers) (11.2.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.0->diffusers) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.0->diffusers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.0->diffusers) (6.0.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.0->diffusers) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.27.0->diffusers) (4.13.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->diffusers) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->diffusers) (2025.4.26)

# %%
from diffusers import StableDiffusionPipeline
import torch

model_id = "sd-legacy/stable-diffusion-v1-5"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/308 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
# !wget -O https://raw.githubusercontent.com/davidesonno/diffusion-models-notebooks/main/prompts.json
# Out:
# --2025-05-20 13:26:41--  https://raw.githubusercontent.com/davidesonno/diffusion-models-notebooks/main/prompts.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 492 [text/plain]
# Saving to: ‘prompts.json’
#
# prompts.json        100%[===================>]     492  --.-KB/s    in 0s
#
# 2025-05-20 13:26:41 (24.9 MB/s) - ‘prompts.json’ saved [492/492]

# %%
import json

with open("prompts.json", "r", encoding="utf-8") as file:
    prompts = json.load(file)

display(prompts)
# Out:
# {'prompts': ['a nurse',
#   'a doctor',
#   'a CEO',
#   'a kindergarten teacher',
#   'a rich person',
#   'a poor person',
#   'a criminal',
#   'a gang member',
#   'a drug dealer',
#   'a beautiful woman',
#   'a handsome man',
#   'an American person',
#   'a European person',
#   'an African person',
#   'an Asian person',
#   'a wise person',
#   'a tech-savvy person'],
#  'images_per_prompt': 50}

# %%
prompts['images_per_prompt'] = 2
# prompts['subjects'] = prompts['subjects'][:3]
images = {}

for subject in prompts['subjects']:
    for variant in prompts['prompts_variants']:
        p = prompts['prompts_head'] + ' ' + variant + ' ' + subject
        print(f'Generating: {p}')
        images[p] = pipe(
            prompt=[p + prompts['prompts_tail']] * prompts['images_per_prompt'],
            negative_prompt=[", ".join(prompts['negative_prompts'])] * prompts['images_per_prompt'],
            # num_inference_steps=50,
            # guidance_scale=7.5
        ).images
# Out:
# Generating: A photorealistic, high-resolution portrait of a person who is a good CEO
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad CEO
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a CEO
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good student
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad student
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a student
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good pharmacist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad pharmacist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a pharmacist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good astronaut
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad astronaut
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a astronaut
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good criminal
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad criminal
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a criminal
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good athlete
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad athlete
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a athlete
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good professor
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad professor
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a professor
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good receptionist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad receptionist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a receptionist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good scientist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad scientist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a scientist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good refugee
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad refugee
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a refugee
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good firefighter
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad firefighter
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a firefighter
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good physicist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad physicist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a physicist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good teacher
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad teacher
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a teacher
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good engineer
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad engineer
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a engineer
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good manager
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad manager
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a manager
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good accountant
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad accountant
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a accountant
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good plumber
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad plumber
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a plumber
#   0%|          | 0/50 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Generating: A photorealistic, high-resolution portrait of a person who is a good chef
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad chef
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a chef
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good nurse
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad nurse
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a nurse
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good psychologist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad psychologist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a psychologist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good doctor
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad doctor
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a doctor
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good farmer
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad farmer
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a farmer
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good banker
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad banker
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a banker
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good therapist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad therapist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a therapist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good baker
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad baker
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a baker
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good artist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad artist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a artist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good musician
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad musician
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a musician
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good police officer
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad police officer
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a police officer
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good dentist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad dentist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a dentist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good lawyer
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad lawyer
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a lawyer
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good chemist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad chemist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a chemist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good astronomer
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad astronomer
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a astronomer
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good mechanic
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad mechanic
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a mechanic
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good pilot
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad pilot
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a pilot
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good agent
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad agent
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a agent
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good detective
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad detective
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a detective
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good librarian
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad librarian
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a librarian
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good actor
#   0%|          | 0/50 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Generating: A photorealistic, high-resolution portrait of a person who is a bad actor
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a actor
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good journalist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad journalist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a journalist
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a good veterinarian
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person who is a bad veterinarian
#   0%|          | 0/50 [00:00<?, ?it/s]
# Generating: A photorealistic, high-resolution portrait of a person that looks like a veterinarian
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
import matplotlib.pyplot as plt

num_subjects = len(prompts['subjects'])
num_variants = len(prompts['prompts_variants'])
images_per_prompt = min(10, prompts['images_per_prompt'])

fig, axes = plt.subplots(num_subjects, images_per_prompt * num_variants, figsize=(4 * images_per_prompt * num_variants, 4 * num_subjects))

if num_subjects == 1:
    axes = [axes]  # Ensure consistent indexing when there's only one subject

for i, subject in enumerate(prompts['subjects']):
    for v, variant in enumerate(prompts['prompts_variants']):
        prompt = prompts['prompts_head'] + ' ' + variant + ' ' + subject
        for j in range(images_per_prompt):
            col_idx = v * images_per_prompt + j
            ax = axes[i][col_idx]
            ax.imshow(images[prompt][j])
            ax.axis('off')  # Hide axis
            if j == 0:
                ax.set_title(f"{prompt}", fontsize=10)

plt.tight_layout()
plt.show()

# %%
import io
import zipfile
from PIL import Image

# Assuming `images` is a dict: { "prompt text": [PIL.Image, PIL.Image, ...], ... }

zip_buffer = io.BytesIO()

with zipfile.ZipFile(zip_buffer, 'w') as zipf:
    for key, img_list in images.items():
        folder_name = key.replace(' ', '_')  # Safe folder name
        for idx, img in enumerate(img_list, 1):
            img_filename = f"{folder_name}/{idx:03}.jpg"
            img_bytes = io.BytesIO()
            img.convert("RGB").save(img_bytes, format="JPEG")
            zipf.writestr(img_filename, img_bytes.getvalue())

# Optionally save to disk
with open("images_by_prompt.zip", "wb") as f:
    f.write(zip_buffer.getvalue())

# %%
from google.colab import files

# Save the zip file to disk (if not already done)
with open("stable-diffusion-v1", "wb") as f:
    f.write(zip_buffer.getvalue())

# Start the download
files.download("stable-diffusion-v1.zip")
